# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !nvidia-smi

# %%
print(torch.__version__)

# %% [markdown]
# # **Pytorch Fundamentals**

# %% [markdown]
# Scaler: 0-dimentional array

# %%
scaler = torch.tensor(7)
scaler

# %%
scaler.ndim

# %%
scaler.item()

# %% [markdown]
# Vector: 1-dimensional

# %%
vector = torch.tensor([7, 7])
vector

# %%
vector.ndim

# %%
vector.shape

# %% [markdown]
# Matrix: 2-dimensional

# %%
Matrix = torch.tensor([[7, 8],
                       [9, 10]])
Matrix

# %%
Matrix.ndim

# %%
Matrix[1]

# %%
Matrix.shape

# %% [markdown]
# Tensor: 3-dimentional

# %%
Tensor = torch.tensor([[[1, 2, 3],
                        [3, 6, 9],
                        [2, 4, 5]]])
Tensor

# %%
Tensor.ndim

# %%
Tensor.shape

# %%
random_tensor = torch.rand(3,4)
random_tensor

# %%
random_image_size_tensor = torch.rand(size=(224, 224, 3))
random_image_size_tensor.shape, random_image_size_tensor.ndim

# %%
zeros = torch.zeros(size=(3,4))
zeros

# %%
ones = torch.ones(size=(3,4))
ones

# %%
ones.dtype

# %%
rng = torch.arange(1, 11)
rng

# %%
rng1 = torch.arange(start=0, end=1000, step=77)
rng1

# %%
ten_zero = torch.zeros_like(input=rng)
ten_zero

# %%
new_t = torch.full((4,3), 3.14, dtype=torch.float32)
print(new_t)

# %%
X = torch.full_like(new_t, 3.24, dtype=None)
print(X)

# %% [markdown]
# # Tensor Attribute

# %%
float_32_tensor = torch.tensor([3.0, 6.0, 9.0], dtype=None, device=None, requires_grad=False)
float_32_tensor

# %%
float_16_tensor = float_32_tensor.type(torch.float16)
float_16_tensor * float_32_tensor

# %%
x = torch.tensor([[1, 2, 3, 4], [5, 7, 8, 9]])
x.stride()

# %%
i = [[0, 1, 1],
     [2, 0, 2]]

v =  [3, 4, 5]

s = torch.sparse_coo_tensor(i, v, (2,3))
s

# %%
a = torch.rand(2,3)
b = torch.rand(2,5)

c = torch.cat([a,b], 1)
c

# %%
x = torch.arange(0, 100, 10)
x

# %%
torch.min(x), x.min()

# %%
torch.mean(x.type(torch.float32)), x.type(torch.float32).mean()

# %%
torch.sum(x), x.sum()

# %% [markdown]
# positional min & max

# %%
x.argmin()

# %%
x.argmax()

# %%
x = torch.arange(1., 10.)
x, x.shape

# %%
x_reshape =x.reshape(9, 1)
x_reshape, x_reshape.shape

# %%
z = x.view(1, 9)
z, z.shape

# %%
z[:, 0] = 5;
z, x

# %%
z = x_reshape.view(9, 1)
z[:, 0] = 5
z, z.shape

# %%
x_stacked = torch.stack([x, x, x, x], dim=0)
x_stacked

# %%
x_reshape.reshape(1, 9)

# %%
x_reshape.squeeze()

# %%
x_reshape.shape

# %%
x_reshape.squeeze(dim=1)

# %%
x_origin = torch.rand(size=(224, 224, 3))
x_permute = x_origin.permute(2, 0 , 1)

x_origin.shape, x_permute.shape

# %%
x_origin[0,0,0] = 728128
x_origin[0,0,0] , x_permute[0, 0, 0]

# %%
x = torch.arange(1, 10).reshape(1, 3, 3)
x, x.shape

# %%
x[0], x[0][0]

# %%
arr = np.arange(1.0, 8.0)
tensor = torch.from_numpy(arr)
arr, tensor

# %%
arr.dtype, torch.arange(1.0, 8.0).dtype

# %%
arr = arr + 1
arr, tensor

# %%
tensor = torch.ones(7)
num_ten = tensor.numpy()
tensor, num_ten

# %% [markdown]
# # **Reproducbility(trying to take random out of random)**

# %%
import torch

rand_tensor_a = torch.rand(3, 4)
rand_tensor_b = torch.rand(3, 4)

rand_tensor_a, rand_tensor_b

# %%
rand_tensor_a == rand_tensor_b

# %%
RANDOM_SEED = 42
torch.manual_seed(RANDOM_SEED)

rand_tensor_c = torch.rand(3, 4)
torch.manual_seed(RANDOM_SEED)
rand_tensor_d = torch.rand(3, 4)

rand_tensor_c, rand_tensor_d

# %%
rand_tensor_c == rand_tensor_d

# %% [markdown]
# Accessing GPU

# %%
torch.cuda.is_available()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device

# %%
torch.cuda.device_count()

# %%
tensor = torch.tensor([1, 2, 3])
tensor, tensor.device

# %%
tensor_gpu = tensor.to(device)
tensor_gpu

# %%
tensor_back = tensor_gpu.cpu().numpy()
tensor_back

# %% [markdown]
# ## **Excersie**

# %%
X = torch.rand(7, 7)
y = torch.rand(1, 7)
y_reshape = y.reshape(7, 1)

# %%
mul = torch.matmul(X, y_reshape)
mul

# %%
RANDOM_SEED = 0
torch.manual_seed(RANDOM_SEED)
X1 = torch.rand(7, 7)
y1 = torch.rand(1, 7)
y1_reshape = y.reshape(7, 1)

mul = torch.matmul(X1, y1_reshape)
mul

# %%
torch.cuda.manual_seed(1234)

# %%
torch.cuda.manual_seed_all(1234)

# %%
torch.manual_seed(1234)

device = "cuda" if torch.cuda.is_available() else "cpu"

t1 = torch.rand(2,3).to(device)
t2 = torch.rand(2,3).to(device)

t1, t2

# %%
res = torch.matmul(t1, t2.T)
res

# %%
res.max(), res.min()

# %%
res.argmax(), res.argmin()

# %%
torch.manual_seed(7)

t3 = torch.rand(1,1,1,10)
t3_squeezed = t3.squeeze()
t3.shape, t3_squeezed.shape

# %% [markdown]
# # **AutoGrad**

# %%
x = torch.tensor(3.0, requires_grad=True)
y = x**2

# %%
x, y

# %%
y.backward()
x.grad

# %%
x = torch.tensor(4.0, requires_grad=True)
y = x**2
z = torch.sin(y)
x, y, z

# %%
z.backward()
x.grad

# %%
y.grad

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

def bin_cross_loss(pred, target):
    ep = 1e-8
    pred = torch.clamp(pred, ep, 1- ep)
    return -(target * torch.log(pred) + (1 - target)*torch.log(1- pred))

z = w*x + b;
y_pred = torch.sigmoid(z);

loss = bin_cross_loss(y_pred, y)
loss

# %%
dloss_dy_pred = (y_pred - y) / (y_pred*(1-y_pred))
dy_pred_dz = y_pred * (1 - y_pred)

dz_dw = x
dz_db = 1

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

z = w*x + b
y_pred = torch.sigmoid(z)
z, y_pred

# %%
import torch.nn.functional as F

# %%
loss = F.binary_cross_entropy(y_pred, y)
loss

# %%
loss.backward()
print(w.grad)
print(b.grad)

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = (x**2).mean()

# %%
y.backward()
x.grad

# %% [markdown]
# # **Clearing Grad**

# %%
x = torch.tensor(2.0, requires_grad=True)
y = (x**2).mean()
y.backward()
x.grad

# %%
x.grad.zero_()

# %% [markdown]
# # **Disable Gradient Tracking**

# %%
x = torch.tensor(2.0, requires_grad=True)
y = (x**2).mean()
y.backward()
x.grad

# %%
x.requires_grad_(False)

# %%
y.backward()

# %%
x = torch.tensor(2.0, requires_grad=True)
z = x.detach()
y = (x**2).mean()

y1 = z**2
y.backward()

# %%
y1.backward()

# %%
with torch.no_grad():
   y = x ** 2
